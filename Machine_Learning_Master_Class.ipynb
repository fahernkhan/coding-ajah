# %% [markdown]
# <a href="https://colab.research.google.com/github/fahernkhan/coding-ajah/blob/main/Machine_Learning_Master_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **100 day with coding**

# %% [markdown]
# # Day 1
# Day 4/30 Machine Learning Master Class - Sanjay - Pantech.ai | Warriorsway | Pantech Solutions
# (salary estimation with KNN)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()

# %%
dataset = pd.read_csv()
dataset

# %%
print (dataset.shape)

# %% [markdown]
# sagragate

# %%
x =
y= dataset.iloc[:,-1].values
y

# %%
# !pip install scikit-learn

# %% [markdown]
# ![image.png](data:image/png;base64,...)
