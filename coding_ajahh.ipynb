# %% [markdown]
# <a href="https://colab.research.google.com/github/fahernkhan/coding-ajah/blob/main/coding_ajahh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **100 day with coding**

# %% [markdown]
# # Day 1
# Day 4/30 Machine Learning Master Class - Sanjay - Pantech.ai | Warriorsway | Pantech Solutions
# (salary estimation with KNN)![Screenshot (2813).png](data:image/png;base64,...)

# %% [markdown]
# # Day 2
# Dasar pemrograman Data science
